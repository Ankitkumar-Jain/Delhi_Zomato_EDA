# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('zomato.csv', encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # Statistical info of numerical data

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# Stats shows the maximum average cost for two person is 800000

# %%
df[df['Average Cost for two']==800000][['Restaurant Name','City','Average Cost for two','Rating text']]
# Out:
#                Restaurant Name     City  Average Cost for two Rating text
# 9283                      Skye  Jakarta                800000   Very Good
# 9284  Satoo - Hotel Shangri-La  Jakarta                800000   Excellent

# %%
df[df['Average Cost for two']==0][['Restaurant Name','City','Average Cost for two','Rating text']]
# Out:
#                      Restaurant Name       City  Average Cost for two  \
# 84                     Cookie Shoppe     Albany                     0
# 85     El Vaquero Mexican Restaurant     Albany                     0
# 87    Pearly's Famous Country Cookng     Albany                     0
# 201                         Deorio's   Columbus                     0
# 240                           Azteca  Davenport                     0
# 277    Happy Joe's Pizza & Ice Cream    Dubuque                     0
# 346             HI Lite Bar & Lounge     Miller                     0
# 397                      Royal Hotel  Pocatello                     0
# 407                    Senor Iguanas  Pocatello                     0
# 634      The Latitude - Radisson Blu       Agra                     0
# 637                  Sheroes Hangout       Agra                     0
# 639                   Chapter 1 Cafe       Agra                     0
# ...

# %% [markdown]
# #  Statistical info of object type data

# %%
df.describe(include='object')
# Out:
#         Restaurant Name       City                     Address  \
# count              9551       9551                        9551
# unique             7446        141                        8918
# top     Cafe Coffee Day  New Delhi  Dilli Haat, INA, New Delhi
# freq                 83       5473                          11
#
#                Locality            Locality Verbose      Cuisines  \
# count              9551                        9551          9542
# unique             1208                        1265          1825
# top     Connaught Place  Connaught Place, New Delhi  North Indian
# freq                122                         122           936
#
#                   Currency Has Table booking Has Online delivery  \
# count                 9551              9551                9551
# unique                  12                 2                   2
# top     Indian Rupees(Rs.)                No                  No
# ...

# %%
df[df.Cuisines.isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# # Filtering Indian Restaurant basis of Country Code with the req columns

# %%
new_df=df[df['Country Code']==1][['Restaurant ID','Restaurant Name','City','Address','Locality','Average Cost for two','Has Table booking',
                  'Has Online delivery','Is delivering now','Aggregate rating','Rating color','Rating text','Votes']]

# %%
new_df.sample(5)
# Out:
#       Restaurant ID                Restaurant Name       City  \
# 2114       18403465                Tandoor Express    Gurgaon
# 5941       18245296  Crazylicious Cakes N Desserts  New Delhi
# 2121       18382055                           Kuzo    Gurgaon
# 1328       18499452                      Good Food    Gurgaon
# 4869           2601                  Punjabi Jaika  New Delhi
#
#                                             Address                  Locality  \
# 2114       B-215, Supermart 1, DLF Phase 4, Gurgaon  Supermart 1, DLF Phase 4
# 5941            A-28, New Friends Colony, New Delhi        New Friends Colony
# 2121  Gold Souk Mall, Phase 1, Sushant Lok, Gurgaon               Sushant Lok
# 1328                           DLF Phase 2, Gurgaon               DLF Phase 2
# 4869                C-57, Lajpat Nagar 2, New Delhi            Lajpat Nagar 2
#
#       Average Cost for two Has Table booking Has Online delivery  \
# ...

# %%
new_df.shape
# Out:
# (8652, 13)

# %%
new_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'City', 'Address', 'Locality',
#        'Average Cost for two', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# # Renaming Column

# %%
new_df.rename(columns={'Restaurant ID':'res_id','Restaurant Name':'res_name','City':'city','Address':'address',
                      'Locality':'locality','Average Cost for two':'avg_cost_for_two','Has Table booking':'has_table_booking',
                      'Has Online delivery':'has_online_delivery','Is delivering now':'is_delivering_now','Aggregate rating':'rating',
                      'Rating text':'review','Votes':'votes'},inplace=True)

# %%
new_df.isnull().sum()
# Out:
# res_id                 0
# res_name               0
# city                   0
# address                0
# locality               0
# avg_cost_for_two       0
# has_table_booking      0
# has_online_delivery    0
# is_delivering_now      0
# rating                 0
# Rating color           0
# review                 0
# votes                  0
# dtype: int64

# %%
new_df.sample(5)
# Out:
#         res_id              res_name       city  \
# 8080    302727           Cook Du Kdu      Noida
# 6779      1775   Bengal Sweet Corner  New Delhi
# 6034    300620        Pardeep Corner  New Delhi
# 4710    309289  Polka Cakes & Coffee  New Delhi
# 891   18133510       Barbeque Nation  Faridabad
#
#                                                 address  \
# 8080  124, Block 2, Ganga Shopping Complex, Sector 2...
# 6779  AB 13, Community Center, Safdarjung Enclave, S...
# 6034   9005, Chowk Multani Dhanda, Paharganj, New Delhi
# 4710  Shop 5/27, Near Gurudwara, Ramesh Nagar, Kirti...
# 891   2nd Floor, Crown Interiorz Mall, Sector 35, Fa...
#
#                                         locality  avg_cost_for_two  \
# 8080           Ganga Shopping Complex, Sector 29               650
# 6779                                  Safdarjung               550
# 6034                                   Paharganj               300
# ...

# %% [markdown]
# # Total number of restaurant in City

# %%
new_df['city'].value_counts().sort_values(ascending=False)
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Chennai           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Jaipur            20
# Coimbatore        20
# Goa               20
# Indore            20
# Kochi             20
# Kanpur            20
# Vizag             20
# Kolkata           20
# Varanasi          20
# Agra              20
# Surat             20
# Pune              20
# Puducherry        20
# Patna             20
# Mangalore         20
# Ranchi            20
# Ludhiana          20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %% [markdown]
# # Observation:
#
# New Delhi has highest number of restaurant while Panchkula and Mohali have lowest number of restaurant

# %% [markdown]
# #  EDA on New Delhi City

# %% [markdown]
# Filtering the data on the basis of city i.e. New Delhi

# %%
nd = new_df[new_df['city']=='New Delhi']

# %%
nd.sample(5)
# Out:
#         res_id          res_name       city  \
# 7597  18460328     Punjabi Dhaba  New Delhi
# 5582  18424169  Flavours Kitchen  New Delhi
# 7894    301377       Madras Cafe  New Delhi
# 5970  18355004        Cafe Point  New Delhi
# 6125  18433897           Berco's  New Delhi
#
#                                                 address  \
# 7597  Shop BE-106A, Hari Nagar, Near Tilak Nagar, Ne...
# 5582  GF-1, A-12/13, Ansal Building, Commercial Comp...
# 7894       1, H Block, DDA Market, Vikaspuri, New Delhi
# 5970  C-42, Main Road, Industrial Area, Okhla Phase ...
# 6125  Palate of Delhi, Dhaula Kuan Metro Station, Ch...
#
#                            locality  avg_cost_for_two has_table_booking  \
# 7597                    Tilak Nagar               300                No
# 5582                Mukherjee Nagar               700                No
# 7894                      Vikaspuri               300                No
# ...

# %%
sns.catplot(data=nd,x='review',kind='count')
plt.show()

# %% [markdown]
# # Observation
#
# above plot shows that there are more number of restaurant got Average review followed by Not rated and very less number of restaurant are excellent.

# %%
ratings_df = nd.groupby(['rating','review','Rating color'])[['rating','review','Rating color']].size().reset_index().rename(columns={0:'count'})

# %%
plt.figure(figsize=(10,7))
sns.barplot(data = ratings_df,x='rating',y='count',hue='review')
plt.show()

# %% [markdown]
# # Observation
#
# above plot shows that restaurant got rating between 2.5 to 3.4 ---> Average review , 3.5 to 3.9----->Good, 4.0 to 4.5----> Very Good , 4.6 to 4.9----> Excellent

# %%
ratings_df
# Out:
#     rating     review Rating color  count
# 0      0.0  Not rated        White   1425
# 1      1.9       Poor          Red      2
# 2      2.0       Poor          Red      2
# 3      2.1       Poor          Red      8
# 4      2.2       Poor          Red     14
# 5      2.3       Poor          Red     25
# 6      2.4       Poor          Red     46
# 7      2.5    Average       Orange     64
# 8      2.6    Average       Orange    129
# 9      2.7    Average       Orange    170
# 10     2.8    Average       Orange    216
# 11     2.9    Average       Orange    253
# 12     3.0    Average       Orange    318
# 13     3.1    Average       Orange    358
# 14     3.2    Average       Orange    353
# 15     3.3    Average       Orange    332
# 16     3.4    Average       Orange    302
# 17     3.5       Good       Yellow    286
# 18     3.6       Good       Yellow    251
# 19     3.7       Good       Yellow    231
# 20     3.8       Good       Yellow    200
# ...

# %% [markdown]
# # Restaurant that provide online delivery facility

# %%
has_online_delivery=nd.has_online_delivery.value_counts()

# %%
plt.pie(x=has_online_delivery.values,labels=has_online_delivery.index,textprops={'fontsize':14},autopct='%1.1f%%')
plt.show()
